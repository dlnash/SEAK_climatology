# %%
import urllib
import json
import yaml
import pandas as pd
import matplotlib.pyplot as plt

# %%
## TODO put this in a yml file and import from there

# import configuration file for station choice
config_name = 'casedec2020' # dictionary name
yaml_doc = 'mesonet_config.yml'
config = yaml.load(open(yaml_doc), Loader=yaml.SafeLoader)
ddict = config[config_name]

stn_ids = []


precip_varnames = ['precip_accum', 'precip_accum_one_minute', 'precip_accum_ten_minute',
                   'precip_accum_fifteen_minute', 'precip_accum_30_minute', 'precip_accum_one_hour',
                   'precip_accum_three_hour', 'precip_storm', 'precip_accum_six_hour', 
                   'precip_accum_24_hour', 'precip_smoothed', 'precip_manual', 'precip_accum_manual',
                   'precip_accum_5_minute_manual', 'precip_accum_10_minute_manual', 'precip_accum_15_minute_manual', 
                   'precip_accum_3_hour_manual', 'precip_accum_6_hour_manual', 'precip_accum_24_hour_manual',
                   'precip_interval', 'precip_accum_since_00utc', 'precip_accum_since_local_midnight', 'precip_accum_12_hour',
                   'precip_accum_five_minute', 'precip_accum_since_7_local']

# %%
ddict['stids'] = 'PAHN'
ddict
# Out:
# {'start': '202011280000',
#  'end': '202012040000',
#  'obtimezone': 'UTC',
#  'stids': 'PAHN',
#  'token': '6f7bc78232734beab9da77235a2bd351',
#  'stnids': 'PAHN'}

# %%
## pull data
apiString = urllib.parse.urlencode(ddict)
url = "http://api.mesowest.net/v2/stations/timeseries"
fullUrl = '{}?{}'.format(url,apiString)
print(fullUrl)
response = urllib.request.urlopen(fullUrl)
responseDict = json.loads(response.read())
# Out:
# http://api.mesowest.net/v2/stations/timeseries?start=202011280000&end=202012040000&obtimezone=UTC&stids=PAHN&token=6f7bc78232734beab9da77235a2bd351&stnids=PAHN

# %%
dictkeys = responseDict['STATION'][0]['OBSERVATIONS'].keys()
dictkeys
# Out:
# dict_keys(['altimeter_set_1', 'wind_cardinal_direction_set_1d', 'wind_gust_set_1', 'pressure_change_code_set_1', 'cloud_layer_3_code_set_1', 'wind_chill_set_1d', 'weather_summary_set_1d', 'sea_level_pressure_set_1', 'sea_level_pressure_set_1d', 'relative_humidity_set_1', 'cloud_layer_1_code_set_1', 'cloud_layer_1_set_1d', 'weather_condition_set_1d', 'air_temp_low_6_hour_set_1', 'air_temp_high_24_hour_set_1', 'precip_accum_one_hour_set_1', 'visibility_set_1', 'pressure_tendency_set_1', 'pressure_set_1d', 'peak_wind_direction_set_1', 'metar_set_1', 'cloud_layer_2_code_set_1', 'peak_wind_speed_set_1', 'wind_speed_set_1', 'precip_accum_24_hour_set_1', 'precip_accum_three_hour_set_1', 'air_temp_set_1', 'air_temp_high_6_hour_set_1', 'date_time', 'dew_point_temperature_set_1d', 'ceiling_set_1', 'dew_point_temperature_set_1', 'air_temp_low_24_hour_set_1', 'cloud_layer_2_set_1d', 'precip_accum_six_hour_set_1', 'metar_origin_set_1', 'cloud_layer_3_set_1d', 'weather_cond_code_set_1', 'wind_direction_set_1'])

# %%
dateTime = responseDict['STATION'][0]['OBSERVATIONS']['date_time']
newvar = responseDict['STATION'][0]['OBSERVATIONS']['precip_accum_one_hour_set_1']
ksea = pd.Series(newvar,index=pd.to_datetime(dateTime))

ksea.plot()
# Out:
# <AxesSubplot:>

# %%
ksea
# Out:
# 2020-11-28 00:54:00+00:00   NaN
# 2020-11-28 01:09:00+00:00   NaN
# 2020-11-28 01:54:00+00:00   NaN
# 2020-11-28 02:54:00+00:00   NaN
# 2020-11-28 03:15:00+00:00   NaN
#                              ..
# 2020-12-03 23:15:00+00:00   NaN
# 2020-12-03 23:20:00+00:00   NaN
# 2020-12-03 23:25:00+00:00   NaN
# 2020-12-03 23:30:00+00:00   NaN
# 2020-12-03 23:54:00+00:00   NaN
# Length: 526, dtype: float64

# %%
ksea = ksea.where(ksea.index.minute == 53).dropna()
ksea.plot()
# Out:
# <AxesSubplot:>

# %%
isinstance(v, collections.abc.Mapping)
for i, varname in enumerate(precip_varnames):
    # check to see if precip var is available
    
    newvar = responseDict['STATION'][0]['OBSERVATIONS']['precip_accum_one_hour_set_1']

from collections.abc import Mapping

if isinstance(precip_varnames, Mapping):
    print('yes')
    
#     try:
#     items = any_object.items()
# except (AttributeError, TypeError):
#     non_items_behavior(any_object)
# else: # no exception raised
#     for item in items: ...
