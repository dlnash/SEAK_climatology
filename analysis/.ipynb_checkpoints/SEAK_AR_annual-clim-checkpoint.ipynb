# %%
# Import Python modules
import os, sys
import yaml
from pathlib import Path
import numpy as np
import numpy.ma as ma
import pandas as  pd
import xarray as xr
from sklearn.cluster import KMeans
from itertools import cycle
from datetime import datetime, timedelta
# matplotlib
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1 import AxesGrid
from matplotlib.colors import ListedColormap
from matplotlib import rcParams
import matplotlib.ticker as mticker
# cartopy
import cartopy.crs as ccrs
from cartopy.mpl.geoaxes import GeoAxes
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
# plot styles/formatting
import seaborn as sns
import cmocean.cm as cmo
import cmocean

from IPython.display import Image, display
from scipy import stats

# Path to modules
sys.path.append('../modules')

# Import my modules
from plotter import draw_basemap
from timeseries import persistence, select_months
from ar_funcs import get_ar_days, duration_stats
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/dnash/miniconda3/envs/SEAK-clim/share/proj failed

# %%
# Set up paths

path_to_data = '/work/dnash/SEAK_clim_data/downloads/AR_catalog/'      # project data -- read only
path_to_out  = '../out/'       # output files (numerical results, intermediate datafiles) -- read & write
path_to_figs = '../figs/'      # figures

# %%
# label strings
ivt_units = 'kg m$^{-1}$ s$^{-1}$'

# Select lat/lon grid
# bnds = [360-175., 360-120., 50., 60.] # extend of AK
bnds = [360-141., 360-130., 54., 61.] # extent of SEAK
lonmin, lonmax, latmin, latmax = bnds

# set start and end dates
start_date = '1979-01-01 0:00'
end_date = '2019-12-31 18:00'

# %%
# %%time
filename =  'globalARcatalog_ERA-Interim_1979-2019_v3.0.nc'
ar_filename = path_to_data + filename
ds = xr.open_dataset(ar_filename)

da = ds.sel(time=slice(start_date, end_date), lat=slice(latmin, latmax), lon=slice(lonmin, lonmax))
da = da.kidmap.squeeze()
da
# Out:
# CPU times: user 67.8 ms, sys: 11.9 ms, total: 79.8 ms
# Wall time: 308 ms
# <xarray.DataArray 'kidmap' (time: 59412, lat: 5, lon: 8)>
# [2376480 values with dtype=float64]
# Coordinates:
#   * lon      (lon) float64 219.0 220.5 222.0 223.5 225.0 226.5 228.0 229.5
#   * lat      (lat) float64 54.0 55.5 57.0 58.5 60.0
#     lev      float64 1e+03
#   * time     (time) datetime64[ns] 1979-01-01 ... 2019-08-31T18:00:00
#     ens      float64 1.0
# Attributes:
#     long_name:  Track ID
#     units:      none

# %%
# number of days
ar_da = da.count(dim='time')/4.
ar_da
# Out:
# <xarray.DataArray 'kidmap' (lat: 5, lon: 8)>
# array([[1668.25, 1677.75, 1685.  , 1695.  , 1696.  , 1675.25, 1642.5 ,
#         1595.5 ],
#        [1626.5 , 1640.  , 1661.75, 1660.  , 1634.  , 1612.5 , 1583.75,
#         1532.  ],
#        [1584.25, 1592.25, 1600.  , 1585.  , 1564.5 , 1542.75, 1513.25,
#         1476.75],
#        [1520.25, 1509.75, 1509.25, 1499.5 , 1488.75, 1450.25, 1416.75,
#         1396.75],
#        [1440.75, 1423.  , 1399.75, 1405.5 , 1388.  , 1357.25, 1317.5 ,
#         1278.75]])
# Coordinates:
#   * lon      (lon) float64 219.0 220.5 222.0 223.5 225.0 226.5 228.0 229.5
#   * lat      (lat) float64 54.0 55.5 57.0 58.5 60.0
#     lev      float64 1e+03
#     ens      float64 1.0

# %%
# Set up projection
mapcrs = ccrs.Mercator()
datacrs = ccrs.PlateCarree()

# Set tick/grid locations
dx = np.arange(lonmin,lonmax+10,10)
dy = np.arange(latmin,latmax+10,10)

# Data for plotting
data = ar_da
lons = data.lon.values
lats = data.lat.values

# %%
# Create figure
fig = plt.figure(figsize=(10,11))
nrows = 1
ncols = 1

# Set up Axes Grid
axes_class = (GeoAxes,dict(map_projection=mapcrs))
axgr = AxesGrid(fig, 111, axes_class=axes_class,
                nrows_ncols=(nrows, ncols), axes_pad = 0.25,
                cbar_location='bottom', cbar_mode='single',
                cbar_pad=0.01, cbar_size='5%',label_mode='')

# cmap setup
cmap = 'Oranges'
cflevs = np.arange(0, 32, 2)

# Loop for drawing each plot
for k, ax in enumerate(axgr):
    ax = draw_basemap(ax, extent=[lonmin,lonmax,latmin,latmax], xticks=dx, yticks=dy)
    
    # Contour Filled

    cf = ax.contourf(lons, lats, data.values, transform=datacrs,
                    cmap=cmap, extend='max')
    
    # Subtitles
    ax.set_title('AR Frequency Jan 1979 to Dec 2019', loc='left', fontsize=13)

# Colorbar (single)
cb = fig.colorbar(cf, axgr.cbar_axes[0], orientation='horizontal', drawedges=True)
cb.set_label('# AR days', fontsize=11)
cb.ax.tick_params(labelsize=10)
    
# Save figure
filepath = path_to_figs + 'AR_freq_jan1979-dec2019' + '.png'
plt.savefig(filepath, dpi=300, bbox_inches='tight')

# Show
plt.show()
# Out:
# /home/dnash/miniconda3/envs/SEAK-clim/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:406: UserWarning: The `map_projection` keyword argument is deprecated, use `projection` to instantiate a GeoAxes instead.
#   warnings.warn("The `map_projection` keyword argument is "

# %%
# create list of lists of trackIDs for each time step
date_lst = da.time.values
final_lst = []
for i, ids in enumerate(date_lst):
#     print(ids)
    # pull track ID list for each time step
    x = da.sel(time=ids).values.flatten()
    result = x[np.logical_not(np.isnan(x))]
    trackID = np.unique(result)
    for j in range(len(trackID)):
        final_lst.append([ids, trackID[j]])
    
# put final_lst into df
track_df = pd.DataFrame(final_lst, columns=['date', 'trackID'])
track_df
track_ids = track_df.trackID.unique()
# create df with trackID, start date, end date, and duration of AR
data = []
for i, ids in enumerate(track_ids):
    idx = (track_df.trackID == ids)
    test = track_df.loc[idx]
    start = test.date.min()
    stop = test.date.max()
    tmp = (test.date.max() - test.date.min()) + timedelta(hours=6)
    duration = tmp.total_seconds()/(3600) # convert to number of hours
    
    data.append([ids, start, stop, duration])
    
duration_df = pd.DataFrame(data, columns=['trackID', 'start_date', 'end_date', 'duration'])
duration_df
# Out:
#            trackID          start_date            end_date  duration
# 0     1.979010e+11 1979-01-01 00:00:00 1979-01-01 00:00:00       6.0
# 1     1.979010e+11 1979-01-03 00:00:00 1979-01-05 06:00:00      60.0
# 2     1.979011e+11 1979-01-09 18:00:00 1979-01-10 00:00:00      12.0
# 3     1.979011e+11 1979-01-16 12:00:00 1979-01-17 00:00:00      18.0
# 4     1.979012e+11 1979-01-18 00:00:00 1979-01-18 18:00:00      24.0
# ...            ...                 ...                 ...       ...
# 3597  2.019082e+11 2019-08-16 00:00:00 2019-08-21 06:00:00     132.0
# 3598  2.019082e+11 2019-08-21 12:00:00 2019-08-22 06:00:00      24.0
# 3599  2.019082e+11 2019-08-22 12:00:00 2019-08-22 18:00:00      12.0
# 3600  2.019082e+11 2019-08-23 12:00:00 2019-08-24 00:00:00      18.0
# 3601  2.019083e+11 2019-08-26 18:00:00 2019-08-27 00:00:00      12.0
#
# [3602 rows x 4 columns]

# %% [markdown]
# ### Get simple list of days an AR is present

# %%
from datetime import timedelta, date

def daterange(date1, date2):
    for n in range(int ((date2 - date1).days)+1):
        return date1 + timedelta(n)

# %%
# Get list of AR time steps from the start-stop dates
dt_lst = []
for index, row in duration_df.iterrows():
    dt = daterange(row['start_date'], row['end_date'])
    dt_lst.append(dt.strftime("%Y-%m-%d"))

# %%
# put into dataframe
d = {'ar_dates': dt_lst}
df = pd.DataFrame(data=d)

# keep only unique dates
df.index = pd.to_datetime(df.ar_dates)
df_new = df.ar_dates.unique()
d = {'ar_dates': df_new}
df = pd.DataFrame(data=d)
df.index = pd.to_datetime(df.ar_dates)
df = df.drop(['ar_dates'], axis=1)
df = df.reset_index()
df = df.rename(columns={"ar_dates": "dates"})
df['ar'] = 1
df
# Out:
#           dates  ar
# 0    1979-01-01   1
# 1    1979-01-03   1
# 2    1979-01-09   1
# 3    1979-01-16   1
# 4    1979-01-18   1
# ...         ...  ..
# 3338 2019-08-16   1
# 3339 2019-08-21   1
# 3340 2019-08-22   1
# 3341 2019-08-23   1
# 3342 2019-08-26   1
#
# [3343 rows x 2 columns]

# %%
## import impact dates list
fpath = '/home/dnash/SEAK_clim_data/downloads/'
fname = 'SEAK_flood_catalog.csv'

impact_df = pd.read_csv(fpath+fname, header=0, sep=',', engine='python', parse_dates=['Impact dates'])
impact_df = impact_df.drop(['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'], axis=1)
# impact_df.index = pd.to_datetime(impact_df['Impact dates'])
impact_df = impact_df.rename(columns={"Impact dates": "dates"})
impact_df
# Out:
#      Impact Level      dates                           Impact  \
# 0               1 2022-02-09                    Lake flooding
# 1               2 2022-01-22            Flood stage, flooding
# 2               2 2022-01-22  Flood stage; flooding in Juneau
# 3               2 2022-01-22             Moderate flood stage
# 4               0 2022-01-22              No impacts recorded
# ..            ...        ...                              ...
# 445             1 1982-10-10                     flood stage'
# 446             1 1981-09-11                      flood stage
# 447             3 1981-09-09             Moderate flood stage
# 448             3 1981-09-08             Moderate flood stage
# 449             3 1981-08-09                  Action flooding
#
#                                     Impact Information Impact Source  \
# 0    Minor flooding around ward lake/river area, wa...         HYDRO
# 1    Jordan creek at 7th highest crest; Montana cre...          AHPS
# ...

# %%
# merge impact dates and all AR dates
merged_df = pd.merge(df, impact_df, how='outer', on='dates')
merged_df
# Out:
#           dates   ar  Impact Level                Impact  \
# 0    1979-01-01  1.0           NaN                   NaN
# 1    1979-01-03  1.0           NaN                   NaN
# 2    1979-01-09  1.0           NaN                   NaN
# 3    1979-01-16  1.0           NaN                   NaN
# 4    1979-01-18  1.0           NaN                   NaN
# ...         ...  ...           ...                   ...
# 3739 1982-10-10  NaN           1.0          flood stage'
# 3740 1981-09-11  NaN           1.0           flood stage
# 3741 1981-09-09  NaN           3.0  Moderate flood stage
# 3742 1981-09-08  NaN           3.0  Moderate flood stage
# 3743 1981-08-09  NaN           3.0       Action flooding
#
#                        Impact Information Impact Source  \
# 0                                     NaN           NaN
# 1                                     NaN           NaN
# 2                                     NaN           NaN
# ...

# %%
idx = (merged_df['Impact Level'] > 0) & (merged_df['ar'] > 0)
df2 = merged_df.loc[idx]
df2
# Out:
#           dates   ar  Impact Level  \
# 371  1983-08-22  1.0           1.0
# 372  1983-08-22  1.0           1.0
# 594  1986-07-20  1.0           2.0
# 783  1988-07-18  1.0           2.0
# 822  1988-11-29  1.0           4.0
# 823  1988-11-29  1.0           2.0
# 1034 1991-08-18  1.0           1.0
# 1068 1991-12-20  1.0           2.0
# 1366 1995-09-10  1.0           3.0
# 1691 1999-09-24  1.0           1.0
# 1696 1999-10-20  1.0           1.0
# 1757 2000-07-24  1.0           2.0
# 1758 2000-07-24  1.0           2.0
# 1770 2000-08-22  1.0           2.0
# 1953 2002-09-21  1.0           2.0
# 1954 2002-09-21  1.0           2.0
# 2280 2006-09-01  1.0           1.0
# 2342 2007-06-09  1.0           1.0
# 2343 2007-06-09  1.0           1.0
# 2539 2009-11-14  1.0           2.0
# 2540 2009-11-14  1.0           2.0
# 2689 2011-08-23  1.0           2.0
# 2765 2012-06-23  1.0           2.0
# 2858 2013-07-07  1.0           2.0
# 2859 2013-07-07  1.0           2.0
# ...

# %%
len(df2)
# Out:
# 48

# %%
clim_ct = df.ar.groupby(df.index.month).count()
clim_ct2 = df2.ar.groupby(df2.index.month).count()
clim_ct2
# Out:
# dates
# 1      7
# 6      3
# 7     11
# 8     11
# 9      9
# 10     1
# 11     5
# 12     1
# Name: ar, dtype: int64

# %%
df.index = pd.to_datetime(df.dates)
mon_ar = df.resample("M").count()  # count number of ARs per month
df2.index = pd.to_datetime(df2.dates)
mon_impact = df2.resample("M").count()
mon_ar
# Out:
#             dates  ar
# dates
# 1979-01-31      8   8
# 1979-02-28      1   1
# 1979-03-31      7   7
# 1979-04-30      5   5
# 1979-05-31      8   8
# ...           ...  ..
# 2019-04-30      4   4
# 2019-05-31      7   7
# 2019-06-30      4   4
# 2019-07-31      5   5
# 2019-08-31      9   9
#
# [488 rows x 2 columns]

# %%
mon_impact
# Out:
#             dates  ar  Impact Level  Impact  Impact Information  \
# dates
# 1983-08-31      2   2             2       2                   2
# 1983-09-30      0   0             0       0                   0
# 1983-10-31      0   0             0       0                   0
# 1983-11-30      0   0             0       0                   0
# 1983-12-31      0   0             0       0                   0
# ...           ...  ..           ...     ...                 ...
# 2018-04-30      0   0             0       0                   0
# 2018-05-31      0   0             0       0                   0
# 2018-06-30      0   0             0       0                   0
# 2018-07-31      0   0             0       0                   0
# 2018-08-31      1   1             1       1                   1
#
#             Impact Source  Notes
# dates
# 1983-08-31              2      0
# 1983-09-30              0      0
# 1983-10-31              0      0
# 1983-11-30              0      0
# ...

# %%
mon_ar['month'] = mon_ar.index.month
mon_ar['year'] = mon_ar.index.year

mon_impact['month'] = mon_impact.index.month
mon_impact['year'] = mon_impact.index.year
mon_ar
# Out:
#             dates  ar  month  year
# dates
# 1979-01-31      8   8      1  1979
# 1979-02-28      1   1      2  1979
# 1979-03-31      7   7      3  1979
# 1979-04-30      5   5      4  1979
# 1979-05-31      8   8      5  1979
# ...           ...  ..    ...   ...
# 2019-04-30      4   4      4  2019
# 2019-05-31      7   7      5  2019
# 2019-06-30      4   4      6  2019
# 2019-07-31      5   5      7  2019
# 2019-08-31      9   9      8  2019
#
# [488 rows x 4 columns]

# %%
sns.boxplot(data=mon_ar, x="month", y="ar_dates")
# Out:
# <AxesSubplot:xlabel='month', ylabel='ar_dates'>

# %%
clim_ct = mon_ar.ar.groupby(mon_ar.index.month).mean()
clim_ct_impact = mon_impact.ar.groupby(mon_impact.index.month).count()
clim_ct
# Out:
# dates
# 1     7.780488
# 2     5.829268
# 3     6.365854
# 4     6.000000
# 5     6.512195
# 6     6.121951
# 7     6.341463
# 8     7.731707
# 9     8.150000
# 10    7.825000
# 11    6.175000
# 12    7.425000
# Name: ar, dtype: float64

# %%
fname = path_to_figs + 'ar_barplot'
fmt = 'png'
fig = plt.figure()
fig.set_size_inches((8.0,3.0))
fig.dpi = 300
nplots=1

# Set custom color palette
colors = ["#003660"]
sns.set_palette(sns.color_palette(colors))
columns=['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D']
          
sns.set_style("whitegrid")
# sns.set_context("paper")
sns.despine()

for i in np.arange(nplots):
    ax = fig.add_subplot(1, 1, i+1)
    sns.barplot(x=np.arange(1, 13, 1), y=clim_ct_impact, color='tab:blue')
#     ax.set_title('AR Frequency (1980-2015)', fontsize=12)
    ax.set_ylabel('Average # AR days per month', fontsize=11)
    ax.set_xticklabels(columns, fontsize=12)
#     ax.legend(loc='upper left')
    
# Save the figure
fig.savefig('%s.%s' % (fname, fmt), bbox_inches='tight', dpi=fig.dpi)
fig.clf()

plotFile = fname + '.png'
print(plotFile)
display(Image(plotFile))
# Out:
# ../figs/ar_barplot.png

# %%
# how many hours per AR - check potential categories
pd.unique(duration_df.duration)
# Out:
# array([  6.,  60.,  12.,  18.,  24.,  30.,  66.,  36.,  42.,  54.,  48.,
#         78.,  84.,  96.,  90., 126., 144., 138.,  72., 108., 120., 156.,
#        228., 132., 294., 102., 168., 204., 174., 114., 150., 180., 198.,
#        276., 222.])

# %%
bins = np.array([[0, 24], [24, 72], [72, 5*24], [5*24, 100*24]])
size, freq = duration_stats(duration_df.duration, bins)
print(sum(freq))
print(freq)
freqs= [freq]
# Out:
# 100.0
# [51.30483064963909, 39.33925596890616, 7.245974458634093, 2.109938922820655]

# %%
fname = path_to_figs + 'donut_plot_duration_freq'
fmt = 'png'

# Pie chart
plt_labels = ['SE AK AR Duration']
labels = ['1 day', '2 days', '3-4 days', '>4 days']
#colors
colors = ['#003660','#0BA89A','#DCE1E5', '#FEBC11']
 
fig = plt.figure()
fig.set_size_inches((4.,4.))
fig.dpi = 300
nrows = 1
ncols = 1
nplots = nrows*ncols
for i in np.arange(nplots):
    ax = plt.subplot(nrows, ncols, i+1)
    ax.pie(freqs[i], colors = colors, labels=labels, autopct=None, startangle=90)
    #draw circle
    centre_circle = plt.Circle((0,0),0.70,fc='white')
    ax.add_artist(centre_circle)
    # Equal aspect ratio ensures that pie is drawn as a circle
    ax.axis('equal')  
    plt.title(plt_labels[i], fontsize=13)

plt.tight_layout()
# plt.show()

fig.savefig('%s.%s' %(fname, fmt), bbox_inches='tight', dpi=300)

plotFile = fname + '.png'
print(plotFile)
# Out:
# ../figs/donut_plot_duration_freq.png

# %%
tmp = ds.sel(time=slice(start_date, end_date))
kivty = tmp.kivty.squeeze() # ivty for each trackID
kivtx = tmp.kivtx.squeeze() # ivtx for each trackID
kid = tmp.kid.squeeze() # trackID for indexing
kid
# append ivty and ivtx to df for each trackID
ivty = []
ivtx = []
trID = []

for i, track in enumerate(duration_df.trackID.values):
    idx = kivtx.where(kid == track, drop=True).values
    x = idx[~np.isnan(idx)][0]
    idy = kivty.where(kid == track, drop=True).values
    y = idy[~np.isnan(idy)][0]
    
    # append to lists
    ivtx.append(x)
    ivty.append(y)
    trID.append(track)
# Out:
# KeyboardInterrupt

# %%
duration_df['ivty'] = ivty
duration_df['ivtx'] = ivtx
duration_df['ivt'] = np.sqrt(duration_df.ivty**2 + duration_df.ivtx**2)
duration_df

# %%
outfile = path_to_out + 'AR_track_duration_SEAK.csv'
duration_df.to_csv(outfile)
